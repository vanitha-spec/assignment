# %%
txt = " abc def ghi "
txt.lstrip()
# Out:
# 'abc def ghi '

# %%
txt = " abc def ghi "
txt.strip()
# Out:
# 'abc def ghi'

# %% [markdown]
# #Using Escape Character

# %%
# Using double quotes is not allowed.
mystr = "My favourite TV series is "Game of Thrones""
# Out:
#   Cell In[3], line 2
#     mystr = "My favourite TV series is "Game of Thrones""
#                                         ^
# SyntaxError: invalid syntax

# %%
# Using escape character to allow illegal characters
mystr = "my favourite series is \"Game of Thrones\""
print(mystr)
# Out:
# my favourite series is "Game of Thrones"

# %% [markdown]
# #List

# %% [raw]
# - List is an ordered sequence of items
# - We've a different data types under a list E.g we can have a integer, float, string items in a same list.

# %% [markdown]
# #List Creation

# %%
list1 = [] # Empty list

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2 = [10, 20, 30]   #List of integer numbers

# %%
list3 = [10.77, 30.66, 60.89]  #list of float numbers

# %%
list4 = ['Sita', 'gita', 'rina']  #list of strings

# %%
list5 = ['sita', 25, [40, 30], [60, 100]]  #Nested lists

# %%
list6 = [100, 'sita', 18.987] # List of mixed data types

# %%
list7 = ['sita', 25, [40,30], [180, 98], {'vanitha', 'akshitha'}]

# %%
len(list7)  # length of list
# Out:
# 5

# %% [markdown]
# #List Indexing

# %% [markdown]
# ![image.png](attachment:f8c9e6f2-659a-494d-8c02-7c99f5db919e.png)

# %%
list2[0] #Retriving first element of the list
# Out:
# 10

# %%
list4[0] # retrive first element of the list
# Out:
# 'Sita'

# %%
list4[0][0] #Nested indexing - Access the first character of the first list element
# Out:
# 'S'

# %%
list4[-1] # Last item of the list
# Out:
# 'rina'

# %%
list5[-1] # last item of the list
# Out:
# [60, 100]

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']
mylist[0:3] #Returnallthe items from oth to 3rd index location excluding the item
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5] # List all items from 2nd to 5th index location excluding the item a
# Out:
# ['three', 'four', 'five']

# %%
mylist[:3] # Return first three items
mylist[:2] # Return first two items
# Out:
# ['one', 'two']

# %%
mylist[-3:] #Return last three items
mylist[-2] #Return last two items
# Out:
# 'seven'

# %%
mylist[-3:] #Returns last three items
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:] #returns last two items
# Out:
# ['seven', 'eight']

# %%
mylist[-1] #Returns last item of the list
# Out:
# 'eight'

# %%
mylist[:] # Return whole list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# #Add, Remove & Change Items

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.append('nine') # Add an item to the end of the list
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'nine']

# %%
mylist.insert(9, 'ten')
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine']

# %%
mylist.insert(1, 'ONE') #Adds item at index location 1
mylist
# Out:
# ['one',
#  'ONE',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine']

# %%
mylist.remove('ONE') # Removes the item ONE
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine']

# %%
mylist = ['Keep', 'your', 'eyes', 'on', 'the', 'stars', 'and', 'your', 'feet', 'on', 'the', 'ground']

# %%
mylist[0:3]
# Out:
# ['Keep', 'your', 'eyes']

# %%
mylist[3]
# Out:
# 'on'

# %%
mylist[2:]
mylist[6:]
# Out:
# ['and', 'your', 'feet', 'on', 'the', 'ground']

# %%
mylist[-3:]
# Out:
# ['on', 'the', 'ground']

# %%
mylist.pop() # Remove last item of the list
# Out:
# 'ground'

# %%
mylist.pop(8)
# Out:
# 'feet'

# %%
del mylist[3] #Removes the itemat indexlocation 3
mylist
# Out:
# ['Keep', 'your', 'eyes', 'stars', 'and', 'your', 'on', 'the']

# %%
mylist = ['Concentrate', 'all', 'your', 'thoughts', 'upon', 'the', 'work', 'in', 'hand']
mylist
# Out:
# ['Concentrate', 'all', 'your', 'thoughts', 'upon', 'the', 'work', 'in', 'hand']

# %%
# Change value of the string
mylist[0] = 1
mylist[1] = 2
mylist[2] = 3
mylist
# Out:
# [1, 2, 3, 'thoughts', 'upon', 'the', 'work', 'in', 'hand']

# %%
mylist.clear() # Empty list/ Dellete all item in the list
mylist
# Out:
# []

# %%
del mylist # Delete the whole list
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 del mylist # Delete the whole list
# ----> 2 mylist
#
# NameError: name 'mylist' is not defined

# %% [markdown]
# #COPY LIST

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 = mylist # Creates a new reference "mylist1"

# %%
id(mylist), id(mylist1) #The address of both mylist & mylist1 will be the same
# Out:
# (2337763836800, 2337763836800)

# %%
mylist2 = mylist.copy() # create a copy of the list

# %%
id(mylist2) #The address of mylist2 will be different from mylist because mylist
# Out:
# 2337763935616

# %%
mylist[0] = 1
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1# mylist1 will be also impacted as it is pointing to the same list
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist2 # copy of list won't be impacted due to changes made on the original list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# #JOIN LISTS

# %%
list1 = ['one', 'two', 'three', 'four']
list2 = ['five', 'six', 'seven', 'eight']

# %%
list3 = list1 + list2 #Join two lists by '+' operator
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2)
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# List Memebership

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'one' in list1 # check if 'one' exist in the list
# Out:
# True

# %%
'ten' in list1 # checks if'ten' exist in the list
# Out:
# False

# %%
if 'three' in list1: # check if 'three' exist in the list
    print("three is present in the list")
else: 
    print("three is not present in the list")
# Out:
# three is present in the list

# %%
if 'eleven' in list1: # check if 'eleven' exist in the list
    print('eleven is present in the list')
else:
    print('eleven is not present in the list')
# Out:
# eleven is not present in the list

# %% [markdown]
# Reverse & sort list

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse() # Reverse the list
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1 = list1[::-1] # Reverse the list
list1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 list1 = list1[::-1] # Reverse the list
#       2 list1
#
# TypeError: list[slice(None, None, -1)] is not a generic class

# %%
mylist = [9,5,2,99,12,88,34]
mylist.sort() # sort the list in ascending order
mylist
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort(reverse=True) # Sort list in descending order
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
mylist4 = [88, 76, 45, 38, 55, 63, 887]
sorted(mylist4) #Returns a new sorted list and doesn't change original list
# Out:
# [38, 45, 55, 63, 76, 88, 887]

# %%
mylist4
# Out:
# [88, 76, 45, 38, 55, 63, 887]

# %% [markdown]
# #Loop through a list

# %%
list1
# Out:
# list[slice(None, None, -1)]

# %%
list1 = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
for i in list1:
        print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(list1):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# #COUNT

# %%
list10 = ['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
list10.count('one')
# Number of items "one" occured in the list
# Out:
# 3

# %%
list10.count('three') #Occured the item 'two' in the list
# Out:
# 2

# %%
list10.count('four') #Occured the item 'four' in the list
# Out:
# 1

# %% [markdown]
# ALL/ANY

# %% [raw]
# The all() method returns:
#  * True - If all the elements in the list are true
#  * False - If any element in a list is false
# The any() function returns if any elelments in the list is True. if not, any() return False.

# %%
L1 = [1,2,2,4,0]

# %%
all(L1) #Will return false as one value is false (value 0)
# Out:
# False

# %%
any(L1) #Will return True as we've items in the list with true value
# Out:
# True

# %%
L2 = [1,2,3,4,True,False]

# %%
all(L2)  #Returns false as one value is false
# Out:
# False

# %%
any(L2) # will return true as we've items in the list with true value
# Out:
# True

# %%
L3 = [1,2,3,True]

# %%
all(L3) #
